# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("../Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
#  YOUR CODE GOES HERE
application_df = application_df.drop(['EIN','NAME'], axis=1)
application_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# ...

# %%
# Determine the number of unique values in each column.
#  YOUR CODE GOES HERE
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
#  YOUR CODE GOES HERE
application_count = application_df['APPLICATION_TYPE'].value_counts()
application_count
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T14        3
# T25        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#  YOUR CODE GOES HERE
application_types_to_replace = list(application_count[application_count < 500].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
#  YOUR CODE GOES HERE
classification_count = application_df['CLASSIFICATION'].value_counts()
classification_count
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C1732        1
# C2600        1
# C2570        1
# C4120        1
# C1236        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
#  YOUR CODE GOES HERE
classification_count.loc[classification_count > 1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C6000       15
# C1800       15
# C1250       14
# C8200       11
# C1278       10
# C1238       10
# C1237        9
# C1235        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C2710        3
# C0           3
# C1260        3
# C1256        2
# C1246        2
# C3200        2
# C1234        2
# C1267        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE
classifications_to_replace = list(classification_count.loc[classification_count < 1000].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
#  YOUR CODE GOES HERE
numeric_dummies_df = pd.get_dummies(application_df)
numeric_dummies_df.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                       0
# 1       1   108590              1                       0
# 2       1     5000              0                       0
# 3       1     6692              1                       0
# 4       1   142590              1                       0
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                     1                     0                    0
# 1                     0                     0                    1
# 2                     0                     0                    0
# 3                     0                     0                    1
# 4                     0                     0                    1
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                    0                    0                    0  ...
# ...

# %%
# Split our preprocessed data into our features and target arrays
#  YOUR CODE GOES HERE
y = numeric_dummies_df['IS_SUCCESSFUL']
X = numeric_dummies_df.drop('IS_SUCCESSFUL', axis=1)

# %%
# Split the preprocessed data into a training and testing dataset
#  YOUR CODE GOES HERE
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model (Attempt 1)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE
number_input_features = len(X_train_scaled[0])
hidden_layer1 = 40
hidden_layer2 = 15
nn = tf.keras.models.Sequential()

# First hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=hidden_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=hidden_layer2, activation="relu"))


# Output layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_21 (Dense)            (None, 40)                1760
#
#  dense_22 (Dense)            (None, 15)                615
#
#  dense_23 (Dense)            (None, 1)                 16
#
# ...
# Total params: 2,391
# Trainable params: 2,391
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
#  YOUR CODE GOES HERE
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
#  YOUR CODE GOES HERE
fit_model = nn.fit(X_train_scaled,y_train,epochs=30)
# Out:
# Epoch 1/30
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5767 - accuracy: 0.7196
# Epoch 2/30
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5548 - accuracy: 0.7286
# Epoch 3/30
# 804/804 [==============================] - 1s 930us/step - loss: 0.5519 - accuracy: 0.7293
# Epoch 4/30
# 804/804 [==============================] - 1s 944us/step - loss: 0.5497 - accuracy: 0.7312
# Epoch 5/30
# 804/804 [==============================] - 1s 932us/step - loss: 0.5491 - accuracy: 0.7318
# Epoch 6/30
# 804/804 [==============================] - 1s 971us/step - loss: 0.5487 - accuracy: 0.7319
# Epoch 7/30
# 804/804 [==============================] - 1s 934us/step - loss: 0.5474 - accuracy: 0.7325
# Epoch 8/30
# 804/804 [==============================] - 1s 950us/step - loss: 0.5471 - accuracy: 0.7325
# Epoch 9/30
# 804/804 [==============================] - 1s 940us/step - loss: 0.5469 - accuracy: 0.7330
# Epoch 10/30
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5514 - accuracy: 0.7276 - 235ms/epoch - 877us/step
# Loss: 0.5514201521873474, Accuracy: 0.727580189704895

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE
nn.save("Models/AlphabetSoupCharity_Optimization1.h5")

# %% [markdown]
# # Compile, Train and Evaluate the Model (Attempt 2)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE
number_input_features = len(X_train_scaled[0])
hidden_layer1 = 100
hidden_layer2 = 80
nn_2 = tf.keras.models.Sequential()

# First hidden layer
#  YOUR CODE GOES HERE
nn_2.add(tf.keras.layers.Dense(units=hidden_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
#  YOUR CODE GOES HERE
nn_2.add(tf.keras.layers.Dense(units=hidden_layer2, activation="relu"))


# Output layer
#  YOUR CODE GOES HERE
nn_2.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_2.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_30 (Dense)            (None, 100)               4400
#
#  dense_31 (Dense)            (None, 80)                8080
#
#  dense_32 (Dense)            (None, 1)                 81
#
# ...
# Total params: 12,561
# Trainable params: 12,561
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
#  YOUR CODE GOES HERE
nn_2.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn_2.fit(X_train_scaled,y_train,epochs=80)
# Out:
# Epoch 1/80
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5348 - accuracy: 0.7404
# Epoch 2/80
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5343 - accuracy: 0.7404
# Epoch 3/80
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5343 - accuracy: 0.7395
# Epoch 4/80
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5347 - accuracy: 0.7408
# Epoch 5/80
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5345 - accuracy: 0.7400
# Epoch 6/80
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5349 - accuracy: 0.7405
# Epoch 7/80
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5344 - accuracy: 0.7412
# Epoch 8/80
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5344 - accuracy: 0.7400
# Epoch 9/80
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5341 - accuracy: 0.7407: 0s - loss: 0.5371 - accura
# Epoch 10/80
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_2.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5746 - accuracy: 0.7279 - 176ms/epoch - 656us/step
# Loss: 0.5745683908462524, Accuracy: 0.7279300093650818

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE
nn.save("Models/AlphabetSoupCharity_Optimization2.h5")

# %% [markdown]
# # Compile, Train and Evaluate the Model (Attempt 3)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE
number_input_features = len(X_train_scaled[0])
hidden_layer1 = 180
hidden_layer2 = 100
nn_3 = tf.keras.models.Sequential()

# First hidden layer
#  YOUR CODE GOES HERE
nn_3.add(tf.keras.layers.Dense(units=hidden_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
#  YOUR CODE GOES HERE
nn_3.add(tf.keras.layers.Dense(units=hidden_layer2, activation="relu"))


# Output layer
#  YOUR CODE GOES HERE
nn_3.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_3.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_39 (Dense)            (None, 180)               7920
#
#  dense_40 (Dense)            (None, 100)               18100
#
#  dense_41 (Dense)            (None, 1)                 101
#
# ...
# Total params: 26,121
# Trainable params: 26,121
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn_3.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn_3.fit(X_train_scaled,y_train,epochs=50)
# Out:
# Epoch 1/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5698 - accuracy: 0.7236
# Epoch 2/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5560 - accuracy: 0.7286
# Epoch 3/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5528 - accuracy: 0.7311
# Epoch 4/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5510 - accuracy: 0.7309
# Epoch 5/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5493 - accuracy: 0.7317
# Epoch 6/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5489 - accuracy: 0.7328
# Epoch 7/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5482 - accuracy: 0.7324
# Epoch 8/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5476 - accuracy: 0.7338
# Epoch 9/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5470 - accuracy: 0.7339
# Epoch 10/50
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_3.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5556 - accuracy: 0.7305 - 242ms/epoch - 904us/step
# Loss: 0.555576741695404, Accuracy: 0.7304956316947937

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE
nn.save("Models/AlphabetSoupCharity_Optimization3.h5")
